# %% [markdown]
# # Fit Analyses
#
# Jeroen E. Timmerman [![](data:image/png;base64,...)](https://orcid.org/0009-0003-8208-0509) (University of Amsterdam)

# %%
library(EMC2)
library(stringr)
library(ggplot2)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
# The following objects are masked from 'package:stats':
#
#     filter, lag
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
# Warning: package 'BayesFactor' was built under R version 4.4.2
# Loading required package: coda
# Loading required package: Matrix
# ************
# Welcome to BayesFactor 0.9.12-4.7. If you have questions, please contact Richard Morey (richarddmorey@gmail.com).
#
# Type BFManual() to open the manual.
# ************
# Attaching package: 'BayesFactor'
# The following object is masked from 'package:EMC2':
#
#     compare

# %% [markdown]
# # Upper Censoring

# %%
parsLBA <- c(log(2),3,1,log(2),log(.75),log(.2))
names(parsLBA) <- c("B", "v", "v_lMd", "A", "sv_lMd", "t0")
parsRDM <- c(log(3),1,.4,log(.75),log(.2))
names(parsRDM) <- c("B", "v", "v_lMd", "s_lMd", "t0")
parsLNR <- c(log(.75),log(.65),log(.5),log(.8),log(.4))
names(parsLNR) <- c("m", "m_lMd", "s", "s_lMd", "t0")

# %%
file_names <- list.files("01_simulation/upper_censoring/EMCs")
EMCs <- data.frame()
for (i in file_names){
  load(paste0("01_simulation/upper_censoring/EMCs/", i))
  EMC <- data.frame(EMC = str_remove(i, ".RData"),
                    censoring = str_detect(i, "sM"),
                    model_name = str_extract(i, "LBA|LNR|RDM"),
                    percentage = str_extract(i, "70|90|975")
                    )
  EMCs <- rbind(EMCs, EMC)
}
EMCs <- na.omit(EMCs) # to remove empty sLBA
EMCs$censoring <- factor(EMCs$censoring, c(FALSE, TRUE), c("Truncated", "Censored"))
EMCs$model_name <- factor(EMCs$model_name)
EMCs$percentage <- factor(EMCs$percentage, c(975, 90, 70), c("2.5%", "10%", "30%"))

# %%
pars <- list()
for (i in 1:nrow(EMCs)) {
  pars[[EMCs$EMC[i]]] <- apply(parameters(get(EMCs$EMC[i], envir = globalenv()), selection = "alpha")[,-1], 2, function(x) quantile(x, c(0.025, 0.5, 0.975)))
  EMCs$RMSE[i] <- sqrt(mean((pars[[EMCs$EMC[i]]][2,] - get(paste0("pars", EMCs$model_name[i]), envir = globalenv()))^2))
}

# %%
frequentist <- t.test(RMSE ~ censoring, data = EMCs)
frequentist
# Out:
#     Welch Two Sample t-test
#
# data:  RMSE by censoring
# t = 4.4212, df = 9.1973, p-value = 0.001583
# alternative hypothesis: true difference in means between group Truncated and group Censored is not equal to 0
# 95 percent confidence interval:
#  0.359907 1.109093
# sample estimates:
# mean in group Truncated  mean in group Censored
#               0.8440147               0.1095145

# %%
model <- ttestBF(formula = RMSE ~ censoring, data = EMCs)
model
# Out:
# Bayes factor analysis
# --------------
# [1] Alt., r=0.707 : 58.5073 ±0%
#
# Against denominator:
#   Null, mu1-mu2 = 0
# ---
# Bayes factor type: BFindepSample, JZS

# %%
#| label: RMSD_upper
#| fig-cap: Root Mean Squared Errors for Upper Censoring in Race Models
#| apa-note: For each model and each level of data missing, the RMSE was computed.

ggplot(EMCs, aes(censoring, RMSE, fill = interaction(percentage, censoring, sep = " "))) +
  facet_grid(~ model_name) +
  scale_fill_brewer(palette = "PuOr") +
  geom_bar(position = "dodge", stat = "identity") +
  labs(fill = "Missing")

# %%
parameters_CI <- as.data.frame(t(data.frame(pars)))
for (i in 1:nrow(parameters_CI)) {
  name <- row.names(parameters_CI)[i]
  parameters_CI$censored[i] <- str_detect(name, "sM")
  parameters_CI$model_name[i] <- str_extract(name, "LBA|LNR|RDM")
  parameters_CI$percentage[i] <- str_extract(name, "70|90|975")
  parameters_CI$parameter[i] <- sub(".*\\.", "", name)
  parameters_CI$true_parameter[i] <- 
    get(paste0("pars", parameters_CI$model_name[i]), envir = globalenv())[parameters_CI$parameter[i]]
}

parameters_CI$percentage <- factor(parameters_CI$percentage, c(975, 90, 70), c("2.5%", "10%", "30%"))
parameters_CI$censored <- factor(parameters_CI$censored, c(TRUE, FALSE), c("Censored", "Truncated"))

parameters_CI
# Out:
#                        2.5%          50%       97.5%  censored model_name
# sLBA70.B         1.25045046  1.319918999  1.36225740 Truncated        LBA
# sLBA70.v         4.81559913  5.046150164  5.27094065 Truncated        LBA
# sLBA70.v_lMd     1.14055894  1.188695055  1.24270362 Truncated        LBA
# sLBA70.A         1.25887609  1.323065619  1.38365937 Truncated        LBA
# sLBA70.sv_lMd   -0.45320453 -0.405631092 -0.36185516 Truncated        LBA
# sLBA70.t0       -2.98681535 -2.822268239 -2.46324794 Truncated        LBA
# sLBA90.B         1.56476186  1.599964021  1.63329957 Truncated        LBA
# sLBA90.v         6.67051618  6.944828670  7.21517280 Truncated        LBA
# sLBA90.v_lMd     1.43373951  1.505378852  1.58026082 Truncated        LBA
# sLBA90.A         1.52055455  1.571492165  1.62127793 Truncated        LBA
# sLBA90.sv_lMd   -0.62293175 -0.567727410 -0.51357755 Truncated        LBA
# sLBA90.t0       -2.99516537 -2.973520061 -2.88329151 Truncated        LBA
# sLBA975.B        1.19165914  1.284111684  1.34903227 Truncated        LBA
# sLBA975.v        4.71872662  4.971029762  5.22851374 Truncated        LBA
# sLBA975.v_lMd    1.14143390  1.189979834  1.23860048 Truncated        LBA
# sLBA975.A        1.24349254  1.312421039  1.37970705 Truncated        LBA
# sLBA975.sv_lMd  -0.41667269 -0.372683209 -0.32685765 Truncated        LBA
# sLBA975.t0      -2.95952834 -2.630439983 -2.23744155 Truncated        LBA
# sLNR70.m        -0.10674732 -0.100212227 -0.09573916 Truncated        LNR
# sLNR70.m_lMd    -0.17872621 -0.171290385 -0.16433584 Truncated        LNR
# sLNR70.s        -1.67770033 -1.663560299 -1.64855364 Truncated        LNR
# sLNR70.s_lMd    -0.28101310 -0.255000264 -0.22751259 Truncated        LNR
# sLNR70.t0       -2.99434207 -2.967942341 -2.86518049 Truncated        LNR
# sLNR90.m        -0.01182173  0.006535446  0.01347147 Truncated        LNR
# sLNR90.m_lMd    -0.22291135 -0.214098597 -0.20590563 Truncated        LNR
# sLNR90.s        -1.42797548 -1.413499631 -1.39047814 Truncated        LNR
# sLNR90.s_lMd    -0.26124277 -0.238324121 -0.21470960 Truncated        LNR
# sLBA975.sv_lMd        2.5%    sv_lMd     -0.2876821
# sLBA975.t0            2.5%        t0     -1.6094379
# sLNR70.m               30%         m     -0.2876821
# sLNR70.m_lMd           30%     m_lMd     -0.4307829
# sLNR70.s               30%         s     -0.6931472
# sLNR70.s_lMd           30%     s_lMd     -0.2231436
# sLNR70.t0              30%        t0     -0.9162907
# sLNR90.m               10%         m     -0.2876821
# sLNR90.m_lMd           10%     m_lMd     -0.4307829
# sLNR90.s               10%         s     -0.6931472
# sLNR90.s_lMd           10%     s_lMd     -0.2231436
# sLNR90.t0              10%        t0     -0.9162907
# sLNR975.m             2.5%         m     -0.2876821
# sLNR975.m_lMd         2.5%     m_lMd     -0.4307829
# sLNR975.s             2.5%         s     -0.6931472
# sLNR975.s_lMd         2.5%     s_lMd     -0.2231436
# sLNR975.t0            2.5%        t0     -0.9162907
# sMLBA70.B              30%         B      0.6931472
# sMLBA70.v              30%         v      3.0000000
# sMLBA70.v_lMd          30%     v_lMd      1.0000000
# sMLBA70.A              30%         A      0.6931472
# sMLBA70.sv_lMd         30%    sv_lMd     -0.2876821
# sMLBA70.t0             30%        t0     -1.6094379
# sMLBA90.B              10%         B      0.6931472
# sMLBA90.v              10%         v      3.0000000
# sMLBA90.v_lMd          10%     v_lMd      1.0000000
# sMLBA90.A              10%         A      0.6931472
# sMLBA90.sv_lMd         10%    sv_lMd     -0.2876821
# sMLBA90.t0             10%        t0     -1.6094379
# sMLBA975.B            2.5%         B      0.6931472
# sMLBA975.v            2.5%         v      3.0000000
# sMLBA975.v_lMd        2.5%     v_lMd      1.0000000
# sMLBA975.A            2.5%         A      0.6931472
# sMLBA975.sv_lMd       2.5%    sv_lMd     -0.2876821
# sMLBA975.t0           2.5%        t0     -1.6094379
# sMLNR70.m              30%         m     -0.2876821
# sMLNR70.m_lMd          30%     m_lMd     -0.4307829
# sMLNR70.s              30%         s     -0.6931472
# sMLNR70.s_lMd          30%     s_lMd     -0.2231436
# sMLNR70.t0             30%        t0     -0.9162907
# sMLNR90.m              10%         m     -0.2876821
# sMLNR90.m_lMd          10%     m_lMd     -0.4307829
# sMLNR90.s              10%         s     -0.6931472
# sMLNR90.s_lMd          10%     s_lMd     -0.2231436
# sMLNR90.t0             10%        t0     -0.9162907
# sMLNR975.m            2.5%         m     -0.2876821
# sMLNR975.m_lMd        2.5%     m_lMd     -0.4307829
# sMLNR975.s            2.5%         s     -0.6931472
# sMLNR975.s_lMd        2.5%     s_lMd     -0.2231436
# sMLNR975.t0           2.5%        t0     -0.9162907
# sMRDM70.B              30%         B      1.0986123
# sMRDM70.v              30%         v      1.0000000
# sMRDM70.v_lMd          30%     v_lMd      0.4000000
# sMRDM70.s_lMd          30%     s_lMd     -0.2876821
# sMRDM70.t0             30%        t0     -1.6094379
# sMRDM90.B              10%         B      1.0986123
# sMRDM90.v              10%         v      1.0000000
# sMRDM90.v_lMd          10%     v_lMd      0.4000000
# sMRDM90.s_lMd          10%     s_lMd     -0.2876821
# sMRDM90.t0             10%        t0     -1.6094379
# sMRDM975.B            2.5%         B      1.0986123
# sMRDM975.v            2.5%         v      1.0000000
# sMRDM975.v_lMd        2.5%     v_lMd      0.4000000
# sMRDM975.s_lMd        2.5%     s_lMd     -0.2876821
# sMRDM975.t0           2.5%        t0     -1.6094379
# sRDM70.B               30%         B      1.0986123
# sRDM70.v               30%         v      1.0000000
# sRDM70.v_lMd           30%     v_lMd      0.4000000
# sRDM70.s_lMd           30%     s_lMd     -0.2876821
# sRDM70.t0              30%        t0     -1.6094379
# sRDM90.B               10%         B      1.0986123
# sRDM90.v               10%         v      1.0000000
# sRDM90.v_lMd           10%     v_lMd      0.4000000
# sRDM90.s_lMd           10%     s_lMd     -0.2876821
# sRDM90.t0              10%        t0     -1.6094379
# sRDM975.B             2.5%         B      1.0986123
# sRDM975.v             2.5%         v      1.0000000
# sRDM975.v_lMd         2.5%     v_lMd      0.4000000
# sRDM975.s_lMd         2.5%     s_lMd     -0.2876821
# sRDM975.t0            2.5%        t0     -1.6094379

# %%
#| label: upper_censoring_recoveries
#| fig-cap: "Upper Censored / Truncated Recoveries at Different Levels"
#| fig-alt: ""
#| apa-note: "Race model recoveries separated by model (LBA, LNR and RDM) and censoring vs truncation. Especially the LBA and LNR parameters are on the identity line for censoring, but off the line for truncation. "

# Use recovery.emc {EMC2} to plot recoveries of a single EMC fit
ggplot(parameters_CI, aes(true_parameter, `50%`, color = percentage)) +
  geom_point() +
  geom_abline() +
  geom_errorbar(aes(ymin = `2.5%`, ymax = `97.5%`)) +
  facet_grid(censored ~ model_name, scales = "free_y") +
  # scale_color_brewer(palette = "YlOrRd") +
  ylab("Estimated Parameters") +
  xlab("True Parameters")

# %% [markdown]
# # Censoring Both

# %%
file_names <- list.files("01_simulation/censoring_both/EMCs")
EMCs <- data.frame()
for (i in file_names){
  load(paste0("01_simulation/censoring_both/EMCs/", i))
  EMC <- data.frame(EMC = str_remove(i, ".RData"),
                    censoring = str_detect(i, "sM"),
                    model_name = str_extract(i, "LBA|LNR|RDM"),
                    tail = str_extract(i, "lower|upper|both"),
                    percentage = str_extract(i, "2|10|30|50"),
                    response_known = !str_detect(i, "unknown")
                    )
  assign(EMC$EMC, s)
  EMCs <- rbind(EMCs, EMC)
}

EMCs$censoring <- factor(EMCs$censoring, c(FALSE, TRUE),
                         c("Truncated", "Censored"))
EMCs$model_name <- factor(EMCs$model_name)
EMCs$response_known <- factor(EMCs$response_known, c(FALSE, TRUE),
                              c("unknown", "known"))

# %%
EMCs_expanded <- data.frame()

for (i in 1:nrow(EMCs)) {
  # Retrieve the EMC object for the current row
  emc_data <- get(EMCs$EMC[i], envir = globalenv())
  
  # Extract parameter data (excluding the first column which represents subjects)
  parameter_data <- parameters(emc_data, selection = "alpha")[, -1]
  subject_ids <- parameters(emc_data, selection = "alpha")[, 1]  # Subject column
  
  # Get the list of parameter names
  parameter_names <- colnames(parameter_data)
  
  # Split data by subject
  split_data <- split(parameter_data, subject_ids)
  
  # Compute quantiles and add rows per parameter and subject
  for (subject in names(split_data)) {
    subject_data <- split_data[[subject]]
    
    # Compute quantiles for each parameter
    subject_quantiles <- apply(subject_data, 2, function(x) quantile(x, c(0.25, 0.5, 0.75), na.rm = T))
    
    # Add a row for each parameter
    for (param in parameter_names) {
      EMCs_expanded <- rbind(EMCs_expanded, data.frame(
        EMC = EMCs$EMC[i],
        model_name = EMCs$model_name[i],
        censoring = EMCs$censoring[i],
        tail = EMCs$tail[i],
        percentage = EMCs$percentage[i],
        response_known = EMCs$response_known[i],
        subject = subject,
        parameter_name = param,
        q25 = subject_quantiles[1, param],
        Median = subject_quantiles[2, param],
        q75 = subject_quantiles[3, param],
        true_parameter = get(paste0("pars", EMCs$model_name[i]), envir = globalenv())[param]
      ))
    }
  }
}

# View the expanded dataframe
EMCs_expanded
# Out:
#                           EMC model_name censoring  tail percentage
# B             sLBAboth10known        LBA Truncated  both         10
# v             sLBAboth10known        LBA Truncated  both         10
# v_lMd         sLBAboth10known        LBA Truncated  both         10
# A             sLBAboth10known        LBA Truncated  both         10
# sv_lMd        sLBAboth10known        LBA Truncated  both         10
# t0            sLBAboth10known        LBA Truncated  both         10
# B1            sLBAboth10known        LBA Truncated  both         10
# v1            sLBAboth10known        LBA Truncated  both         10
# v_lMd1        sLBAboth10known        LBA Truncated  both         10
# A1            sLBAboth10known        LBA Truncated  both         10
# sv_lMd1       sLBAboth10known        LBA Truncated  both         10
# t01           sLBAboth10known        LBA Truncated  both         10
# B2            sLBAboth10known        LBA Truncated  both         10
# v2            sLBAboth10known        LBA Truncated  both         10
# v_lMd2        sLBAboth10known        LBA Truncated  both         10
# A2            sLBAboth10known        LBA Truncated  both         10
# sv_lMd2       sLBAboth10known        LBA Truncated  both         10
# t02           sLBAboth10known        LBA Truncated  both         10
# B3            sLBAboth10known        LBA Truncated  both         10
# v3            sLBAboth10known        LBA Truncated  both         10
# v_lMd3        sLBAboth10known        LBA Truncated  both         10
# A3            sLBAboth10known        LBA Truncated  both         10
# sv_lMd3       sLBAboth10known        LBA Truncated  both         10
# t03           sLBAboth10known        LBA Truncated  both         10
# B4            sLBAboth10known        LBA Truncated  both         10
# v4            sLBAboth10known        LBA Truncated  both         10
# v_lMd4        sLBAboth10known        LBA Truncated  both         10
# A4            sLBAboth10known        LBA Truncated  both         10
# sv_lMd4       sLBAboth10known        LBA Truncated  both         10
# t04           sLBAboth10known        LBA Truncated  both         10
# B5            sLBAboth10known        LBA Truncated  both         10
# v5            sLBAboth10known        LBA Truncated  both         10
# v_lMd5        sLBAboth10known        LBA Truncated  both         10
# A5            sLBAboth10known        LBA Truncated  both         10
# sv_lMd5       sLBAboth10known        LBA Truncated  both         10
# t05           sLBAboth10known        LBA Truncated  both         10
# B6            sLBAboth10known        LBA Truncated  both         10
# v6            sLBAboth10known        LBA Truncated  both         10
# v_lMd6        sLBAboth10known        LBA Truncated  both         10
# A6            sLBAboth10known        LBA Truncated  both         10
# sv_lMd6       sLBAboth10known        LBA Truncated  both         10
# t06           sLBAboth10known        LBA Truncated  both         10
# B7            sLBAboth10known        LBA Truncated  both         10
# v7            sLBAboth10known        LBA Truncated  both         10
# v_lMd7        sLBAboth10known        LBA Truncated  both         10
# A7            sLBAboth10known        LBA Truncated  both         10
# sv_lMd7       sLBAboth10known        LBA Truncated  both         10
# t07           sLBAboth10known        LBA Truncated  both         10
# B8            sLBAboth10known        LBA Truncated  both         10
# v8            sLBAboth10known        LBA Truncated  both         10
# v_lMd8        sLBAboth10known        LBA Truncated  both         10
# A8            sLBAboth10known        LBA Truncated  both         10
# sv_lMd8       sLBAboth10known        LBA Truncated  both         10
# t08           sLBAboth10known        LBA Truncated  both         10
# B9            sLBAboth10known        LBA Truncated  both         10
# v9            sLBAboth10known        LBA Truncated  both         10
# v_lMd9        sLBAboth10known        LBA Truncated  both         10
# A9            sLBAboth10known        LBA Truncated  both         10
# sv_lMd9       sLBAboth10known        LBA Truncated  both         10
# t09           sLBAboth10known        LBA Truncated  both         10
# B10         sLBAboth10unknown        LBA Truncated  both         10
# v10         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd10     sLBAboth10unknown        LBA Truncated  both         10
# A10         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd10    sLBAboth10unknown        LBA Truncated  both         10
# t010        sLBAboth10unknown        LBA Truncated  both         10
# B11         sLBAboth10unknown        LBA Truncated  both         10
# v11         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd11     sLBAboth10unknown        LBA Truncated  both         10
# A11         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd11    sLBAboth10unknown        LBA Truncated  both         10
# t011        sLBAboth10unknown        LBA Truncated  both         10
# B12         sLBAboth10unknown        LBA Truncated  both         10
# v12         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd12     sLBAboth10unknown        LBA Truncated  both         10
# A12         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd12    sLBAboth10unknown        LBA Truncated  both         10
# t012        sLBAboth10unknown        LBA Truncated  both         10
# B13         sLBAboth10unknown        LBA Truncated  both         10
# v13         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd13     sLBAboth10unknown        LBA Truncated  both         10
# A13         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd13    sLBAboth10unknown        LBA Truncated  both         10
# t013        sLBAboth10unknown        LBA Truncated  both         10
# B14         sLBAboth10unknown        LBA Truncated  both         10
# v14         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd14     sLBAboth10unknown        LBA Truncated  both         10
# A14         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd14    sLBAboth10unknown        LBA Truncated  both         10
# t014        sLBAboth10unknown        LBA Truncated  both         10
# B15         sLBAboth10unknown        LBA Truncated  both         10
# v15         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd15     sLBAboth10unknown        LBA Truncated  both         10
# A15         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd15    sLBAboth10unknown        LBA Truncated  both         10
# t015        sLBAboth10unknown        LBA Truncated  both         10
# B16         sLBAboth10unknown        LBA Truncated  both         10
# v16         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd16     sLBAboth10unknown        LBA Truncated  both         10
# A16         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd16    sLBAboth10unknown        LBA Truncated  both         10
# t016        sLBAboth10unknown        LBA Truncated  both         10
# B17         sLBAboth10unknown        LBA Truncated  both         10
# v17         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd17     sLBAboth10unknown        LBA Truncated  both         10
# A17         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd17    sLBAboth10unknown        LBA Truncated  both         10
# t017        sLBAboth10unknown        LBA Truncated  both         10
# B18         sLBAboth10unknown        LBA Truncated  both         10
# v18         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd18     sLBAboth10unknown        LBA Truncated  both         10
# A18         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd18    sLBAboth10unknown        LBA Truncated  both         10
# t018        sLBAboth10unknown        LBA Truncated  both         10
# B19         sLBAboth10unknown        LBA Truncated  both         10
# v19         sLBAboth10unknown        LBA Truncated  both         10
# v_lMd19     sLBAboth10unknown        LBA Truncated  both         10
# A19         sLBAboth10unknown        LBA Truncated  both         10
# sv_lMd19    sLBAboth10unknown        LBA Truncated  both         10
# t019        sLBAboth10unknown        LBA Truncated  both         10
# B20            sLBAboth2known        LBA Truncated  both          2
# v20            sLBAboth2known        LBA Truncated  both          2
# v_lMd20        sLBAboth2known        LBA Truncated  both          2
# A20            sLBAboth2known        LBA Truncated  both          2
# sv_lMd20       sLBAboth2known        LBA Truncated  both          2
# t020           sLBAboth2known        LBA Truncated  both          2
# B21            sLBAboth2known        LBA Truncated  both          2
# v21            sLBAboth2known        LBA Truncated  both          2
# v_lMd21        sLBAboth2known        LBA Truncated  both          2
# A21            sLBAboth2known        LBA Truncated  both          2
# sv_lMd21       sLBAboth2known        LBA Truncated  both          2
# t021           sLBAboth2known        LBA Truncated  both          2
# B22            sLBAboth2known        LBA Truncated  both          2
# v22            sLBAboth2known        LBA Truncated  both          2
# v_lMd22        sLBAboth2known        LBA Truncated  both          2
# A22            sLBAboth2known        LBA Truncated  both          2
# sv_lMd22       sLBAboth2known        LBA Truncated  both          2
# t022           sLBAboth2known        LBA Truncated  both          2
# B23            sLBAboth2known        LBA Truncated  both          2
# v23            sLBAboth2known        LBA Truncated  both          2
# v_lMd23        sLBAboth2known        LBA Truncated  both          2
# A23            sLBAboth2known        LBA Truncated  both          2
# sv_lMd23       sLBAboth2known        LBA Truncated  both          2
# t023           sLBAboth2known        LBA Truncated  both          2
# B24            sLBAboth2known        LBA Truncated  both          2
# v24            sLBAboth2known        LBA Truncated  both          2
# v_lMd24        sLBAboth2known        LBA Truncated  both          2
# A24            sLBAboth2known        LBA Truncated  both          2
# sv_lMd24       sLBAboth2known        LBA Truncated  both          2
# t024           sLBAboth2known        LBA Truncated  both          2
# B25            sLBAboth2known        LBA Truncated  both          2
# v25            sLBAboth2known        LBA Truncated  both          2
# v_lMd25        sLBAboth2known        LBA Truncated  both          2
# A25            sLBAboth2known        LBA Truncated  both          2
# sv_lMd25       sLBAboth2known        LBA Truncated  both          2
# t025           sLBAboth2known        LBA Truncated  both          2
# B26            sLBAboth2known        LBA Truncated  both          2
# v26            sLBAboth2known        LBA Truncated  both          2
# v_lMd26        sLBAboth2known        LBA Truncated  both          2
# A26            sLBAboth2known        LBA Truncated  both          2
# sv_lMd26       sLBAboth2known        LBA Truncated  both          2
# t026           sLBAboth2known        LBA Truncated  both          2
# B27            sLBAboth2known        LBA Truncated  both          2
# v27            sLBAboth2known        LBA Truncated  both          2
# v_lMd27        sLBAboth2known        LBA Truncated  both          2
# A27            sLBAboth2known        LBA Truncated  both          2
# sv_lMd27       sLBAboth2known        LBA Truncated  both          2
# t027           sLBAboth2known        LBA Truncated  both          2
# B28            sLBAboth2known        LBA Truncated  both          2
# v28            sLBAboth2known        LBA Truncated  both          2
# v_lMd28        sLBAboth2known        LBA Truncated  both          2
# A28            sLBAboth2known        LBA Truncated  both          2
# sv_lMd28       sLBAboth2known        LBA Truncated  both          2
# t028           sLBAboth2known        LBA Truncated  both          2
# B29            sLBAboth2known        LBA Truncated  both          2
# v29            sLBAboth2known        LBA Truncated  both          2
# v_lMd29        sLBAboth2known        LBA Truncated  both          2
# A29            sLBAboth2known        LBA Truncated  both          2
# sv_lMd29       sLBAboth2known        LBA Truncated  both          2
# t029           sLBAboth2known        LBA Truncated  both          2
# B30          sLBAboth2unknown        LBA Truncated  both          2
# v30          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd30      sLBAboth2unknown        LBA Truncated  both          2
# A30          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd30     sLBAboth2unknown        LBA Truncated  both          2
# t030         sLBAboth2unknown        LBA Truncated  both          2
# B31          sLBAboth2unknown        LBA Truncated  both          2
# v31          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd31      sLBAboth2unknown        LBA Truncated  both          2
# A31          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd31     sLBAboth2unknown        LBA Truncated  both          2
# t031         sLBAboth2unknown        LBA Truncated  both          2
# B32          sLBAboth2unknown        LBA Truncated  both          2
# v32          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd32      sLBAboth2unknown        LBA Truncated  both          2
# A32          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd32     sLBAboth2unknown        LBA Truncated  both          2
# t032         sLBAboth2unknown        LBA Truncated  both          2
# B33          sLBAboth2unknown        LBA Truncated  both          2
# v33          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd33      sLBAboth2unknown        LBA Truncated  both          2
# A33          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd33     sLBAboth2unknown        LBA Truncated  both          2
# t033         sLBAboth2unknown        LBA Truncated  both          2
# B34          sLBAboth2unknown        LBA Truncated  both          2
# v34          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd34      sLBAboth2unknown        LBA Truncated  both          2
# A34          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd34     sLBAboth2unknown        LBA Truncated  both          2
# t034         sLBAboth2unknown        LBA Truncated  both          2
# B35          sLBAboth2unknown        LBA Truncated  both          2
# v35          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd35      sLBAboth2unknown        LBA Truncated  both          2
# A35          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd35     sLBAboth2unknown        LBA Truncated  both          2
# t035         sLBAboth2unknown        LBA Truncated  both          2
# B36          sLBAboth2unknown        LBA Truncated  both          2
# v36          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd36      sLBAboth2unknown        LBA Truncated  both          2
# A36          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd36     sLBAboth2unknown        LBA Truncated  both          2
# t036         sLBAboth2unknown        LBA Truncated  both          2
# B37          sLBAboth2unknown        LBA Truncated  both          2
# v37          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd37      sLBAboth2unknown        LBA Truncated  both          2
# A37          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd37     sLBAboth2unknown        LBA Truncated  both          2
# t037         sLBAboth2unknown        LBA Truncated  both          2
# B38          sLBAboth2unknown        LBA Truncated  both          2
# v38          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd38      sLBAboth2unknown        LBA Truncated  both          2
# A38          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd38     sLBAboth2unknown        LBA Truncated  both          2
# t038         sLBAboth2unknown        LBA Truncated  both          2
# B39          sLBAboth2unknown        LBA Truncated  both          2
# v39          sLBAboth2unknown        LBA Truncated  both          2
# v_lMd39      sLBAboth2unknown        LBA Truncated  both          2
# A39          sLBAboth2unknown        LBA Truncated  both          2
# sv_lMd39     sLBAboth2unknown        LBA Truncated  both          2
# t039         sLBAboth2unknown        LBA Truncated  both          2
# B40           sLBAboth30known        LBA Truncated  both         30
# v40           sLBAboth30known        LBA Truncated  both         30
# v_lMd40       sLBAboth30known        LBA Truncated  both         30
# A40           sLBAboth30known        LBA Truncated  both         30
# sv_lMd40      sLBAboth30known        LBA Truncated  both         30
# t040          sLBAboth30known        LBA Truncated  both         30
# B41           sLBAboth30known        LBA Truncated  both         30
# v41           sLBAboth30known        LBA Truncated  both         30
# v_lMd41       sLBAboth30known        LBA Truncated  both         30
# A41           sLBAboth30known        LBA Truncated  both         30
# sv_lMd41      sLBAboth30known        LBA Truncated  both         30
# t041          sLBAboth30known        LBA Truncated  both         30
# B42           sLBAboth30known        LBA Truncated  both         30
# v42           sLBAboth30known        LBA Truncated  both         30
# v_lMd42       sLBAboth30known        LBA Truncated  both         30
# A42           sLBAboth30known        LBA Truncated  both         30
# sv_lMd42      sLBAboth30known        LBA Truncated  both         30
# t042          sLBAboth30known        LBA Truncated  both         30
# B43           sLBAboth30known        LBA Truncated  both         30
# v43           sLBAboth30known        LBA Truncated  both         30
# v_lMd43       sLBAboth30known        LBA Truncated  both         30
# A43           sLBAboth30known        LBA Truncated  both         30
# sv_lMd43      sLBAboth30known        LBA Truncated  both         30
# t043          sLBAboth30known        LBA Truncated  both         30
# B44           sLBAboth30known        LBA Truncated  both         30
# v44           sLBAboth30known        LBA Truncated  both         30
# v_lMd44       sLBAboth30known        LBA Truncated  both         30
# A44           sLBAboth30known        LBA Truncated  both         30
# sv_lMd44      sLBAboth30known        LBA Truncated  both         30
# t044          sLBAboth30known        LBA Truncated  both         30
# B45           sLBAboth30known        LBA Truncated  both         30
# v45           sLBAboth30known        LBA Truncated  both         30
# v_lMd45       sLBAboth30known        LBA Truncated  both         30
# A45           sLBAboth30known        LBA Truncated  both         30
# sv_lMd45      sLBAboth30known        LBA Truncated  both         30
# t045          sLBAboth30known        LBA Truncated  both         30
# B46           sLBAboth30known        LBA Truncated  both         30
# v46           sLBAboth30known        LBA Truncated  both         30
# v_lMd46       sLBAboth30known        LBA Truncated  both         30
# A46           sLBAboth30known        LBA Truncated  both         30
# sv_lMd46      sLBAboth30known        LBA Truncated  both         30
# t046          sLBAboth30known        LBA Truncated  both         30
# B47           sLBAboth30known        LBA Truncated  both         30
# v47           sLBAboth30known        LBA Truncated  both         30
# v_lMd47       sLBAboth30known        LBA Truncated  both         30
# A47           sLBAboth30known        LBA Truncated  both         30
# sv_lMd47      sLBAboth30known        LBA Truncated  both         30
# t047          sLBAboth30known        LBA Truncated  both         30
# B48           sLBAboth30known        LBA Truncated  both         30
# v48           sLBAboth30known        LBA Truncated  both         30
# v_lMd48       sLBAboth30known        LBA Truncated  both         30
# A48           sLBAboth30known        LBA Truncated  both         30
# sv_lMd48      sLBAboth30known        LBA Truncated  both         30
# t048          sLBAboth30known        LBA Truncated  both         30
# B49           sLBAboth30known        LBA Truncated  both         30
# v49           sLBAboth30known        LBA Truncated  both         30
# v_lMd49       sLBAboth30known        LBA Truncated  both         30
# A49           sLBAboth30known        LBA Truncated  both         30
# sv_lMd49      sLBAboth30known        LBA Truncated  both         30
# t049          sLBAboth30known        LBA Truncated  both         30
# B50         sLBAboth30unknown        LBA Truncated  both         30
# v50         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd50     sLBAboth30unknown        LBA Truncated  both         30
# A50         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd50    sLBAboth30unknown        LBA Truncated  both         30
# t050        sLBAboth30unknown        LBA Truncated  both         30
# B51         sLBAboth30unknown        LBA Truncated  both         30
# v51         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd51     sLBAboth30unknown        LBA Truncated  both         30
# A51         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd51    sLBAboth30unknown        LBA Truncated  both         30
# t051        sLBAboth30unknown        LBA Truncated  both         30
# B52         sLBAboth30unknown        LBA Truncated  both         30
# v52         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd52     sLBAboth30unknown        LBA Truncated  both         30
# A52         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd52    sLBAboth30unknown        LBA Truncated  both         30
# t052        sLBAboth30unknown        LBA Truncated  both         30
# B53         sLBAboth30unknown        LBA Truncated  both         30
# v53         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd53     sLBAboth30unknown        LBA Truncated  both         30
# A53         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd53    sLBAboth30unknown        LBA Truncated  both         30
# t053        sLBAboth30unknown        LBA Truncated  both         30
# B54         sLBAboth30unknown        LBA Truncated  both         30
# v54         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd54     sLBAboth30unknown        LBA Truncated  both         30
# A54         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd54    sLBAboth30unknown        LBA Truncated  both         30
# t054        sLBAboth30unknown        LBA Truncated  both         30
# B55         sLBAboth30unknown        LBA Truncated  both         30
# v55         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd55     sLBAboth30unknown        LBA Truncated  both         30
# A55         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd55    sLBAboth30unknown        LBA Truncated  both         30
# t055        sLBAboth30unknown        LBA Truncated  both         30
# B56         sLBAboth30unknown        LBA Truncated  both         30
# v56         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd56     sLBAboth30unknown        LBA Truncated  both         30
# A56         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd56    sLBAboth30unknown        LBA Truncated  both         30
# t056        sLBAboth30unknown        LBA Truncated  both         30
# B57         sLBAboth30unknown        LBA Truncated  both         30
# v57         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd57     sLBAboth30unknown        LBA Truncated  both         30
# A57         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd57    sLBAboth30unknown        LBA Truncated  both         30
# t057        sLBAboth30unknown        LBA Truncated  both         30
# B58         sLBAboth30unknown        LBA Truncated  both         30
# v58         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd58     sLBAboth30unknown        LBA Truncated  both         30
# A58         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd58    sLBAboth30unknown        LBA Truncated  both         30
# t058        sLBAboth30unknown        LBA Truncated  both         30
# B59         sLBAboth30unknown        LBA Truncated  both         30
# v59         sLBAboth30unknown        LBA Truncated  both         30
# v_lMd59     sLBAboth30unknown        LBA Truncated  both         30
# A59         sLBAboth30unknown        LBA Truncated  both         30
# sv_lMd59    sLBAboth30unknown        LBA Truncated  both         30
# t059        sLBAboth30unknown        LBA Truncated  both         30
# B60           sLBAboth50known        LBA Truncated  both         50
# v60           sLBAboth50known        LBA Truncated  both         50
# v_lMd60       sLBAboth50known        LBA Truncated  both         50
# A60           sLBAboth50known        LBA Truncated  both         50
# sv_lMd60      sLBAboth50known        LBA Truncated  both         50
# t060          sLBAboth50known        LBA Truncated  both         50
# B61           sLBAboth50known        LBA Truncated  both         50
# v61           sLBAboth50known        LBA Truncated  both         50
# v_lMd61       sLBAboth50known        LBA Truncated  both         50
# A61           sLBAboth50known        LBA Truncated  both         50
# sv_lMd61      sLBAboth50known        LBA Truncated  both         50
# t061          sLBAboth50known        LBA Truncated  both         50
# B62           sLBAboth50known        LBA Truncated  both         50
# v62           sLBAboth50known        LBA Truncated  both         50
# v_lMd62       sLBAboth50known        LBA Truncated  both         50
# A62           sLBAboth50known        LBA Truncated  both         50
# sv_lMd62      sLBAboth50known        LBA Truncated  both         50
# t062          sLBAboth50known        LBA Truncated  both         50
# B63           sLBAboth50known        LBA Truncated  both         50
# v63           sLBAboth50known        LBA Truncated  both         50
# v_lMd63       sLBAboth50known        LBA Truncated  both         50
# A63           sLBAboth50known        LBA Truncated  both         50
# sv_lMd63      sLBAboth50known        LBA Truncated  both         50
# t063          sLBAboth50known        LBA Truncated  both         50
# B64           sLBAboth50known        LBA Truncated  both         50
# v64           sLBAboth50known        LBA Truncated  both         50
# v_lMd64       sLBAboth50known        LBA Truncated  both         50
# A64           sLBAboth50known        LBA Truncated  both         50
# sv_lMd64      sLBAboth50known        LBA Truncated  both         50
# t064          sLBAboth50known        LBA Truncated  both         50
# B65           sLBAboth50known        LBA Truncated  both         50
# v65           sLBAboth50known        LBA Truncated  both         50
# v_lMd65       sLBAboth50known        LBA Truncated  both         50
# A65           sLBAboth50known        LBA Truncated  both         50
# sv_lMd65      sLBAboth50known        LBA Truncated  both         50
# t065          sLBAboth50known        LBA Truncated  both         50
# B66           sLBAboth50known        LBA Truncated  both         50
# v66           sLBAboth50known        LBA Truncated  both         50
# v_lMd66       sLBAboth50known        LBA Truncated  both         50
# A66           sLBAboth50known        LBA Truncated  both         50
# sv_lMd66      sLBAboth50known        LBA Truncated  both         50
# t066          sLBAboth50known        LBA Truncated  both         50
# B67           sLBAboth50known        LBA Truncated  both         50
# v67           sLBAboth50known        LBA Truncated  both         50
# v_lMd67       sLBAboth50known        LBA Truncated  both         50
# A67           sLBAboth50known        LBA Truncated  both         50
# sv_lMd67      sLBAboth50known        LBA Truncated  both         50
# t067          sLBAboth50known        LBA Truncated  both         50
# B68           sLBAboth50known        LBA Truncated  both         50
# v68           sLBAboth50known        LBA Truncated  both         50
# v_lMd68       sLBAboth50known        LBA Truncated  both         50
# A68           sLBAboth50known        LBA Truncated  both         50
# sv_lMd68      sLBAboth50known        LBA Truncated  both         50
# t068          sLBAboth50known        LBA Truncated  both         50
# B69           sLBAboth50known        LBA Truncated  both         50
# v69           sLBAboth50known        LBA Truncated  both         50
# v_lMd69       sLBAboth50known        LBA Truncated  both         50
# A69           sLBAboth50known        LBA Truncated  both         50
# sv_lMd69      sLBAboth50known        LBA Truncated  both         50
# t069          sLBAboth50known        LBA Truncated  both         50
# B70         sLBAboth50unknown        LBA Truncated  both         50
# v70         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd70     sLBAboth50unknown        LBA Truncated  both         50
# A70         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd70    sLBAboth50unknown        LBA Truncated  both         50
# t070        sLBAboth50unknown        LBA Truncated  both         50
# B71         sLBAboth50unknown        LBA Truncated  both         50
# v71         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd71     sLBAboth50unknown        LBA Truncated  both         50
# A71         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd71    sLBAboth50unknown        LBA Truncated  both         50
# t071        sLBAboth50unknown        LBA Truncated  both         50
# B72         sLBAboth50unknown        LBA Truncated  both         50
# v72         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd72     sLBAboth50unknown        LBA Truncated  both         50
# A72         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd72    sLBAboth50unknown        LBA Truncated  both         50
# t072        sLBAboth50unknown        LBA Truncated  both         50
# B73         sLBAboth50unknown        LBA Truncated  both         50
# v73         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd73     sLBAboth50unknown        LBA Truncated  both         50
# A73         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd73    sLBAboth50unknown        LBA Truncated  both         50
# t073        sLBAboth50unknown        LBA Truncated  both         50
# B74         sLBAboth50unknown        LBA Truncated  both         50
# v74         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd74     sLBAboth50unknown        LBA Truncated  both         50
# A74         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd74    sLBAboth50unknown        LBA Truncated  both         50
# t074        sLBAboth50unknown        LBA Truncated  both         50
# B75         sLBAboth50unknown        LBA Truncated  both         50
# v75         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd75     sLBAboth50unknown        LBA Truncated  both         50
# A75         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd75    sLBAboth50unknown        LBA Truncated  both         50
# t075        sLBAboth50unknown        LBA Truncated  both         50
# B76         sLBAboth50unknown        LBA Truncated  both         50
# v76         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd76     sLBAboth50unknown        LBA Truncated  both         50
# A76         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd76    sLBAboth50unknown        LBA Truncated  both         50
# t076        sLBAboth50unknown        LBA Truncated  both         50
# B77         sLBAboth50unknown        LBA Truncated  both         50
# v77         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd77     sLBAboth50unknown        LBA Truncated  both         50
# A77         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd77    sLBAboth50unknown        LBA Truncated  both         50
# t077        sLBAboth50unknown        LBA Truncated  both         50
# B78         sLBAboth50unknown        LBA Truncated  both         50
# v78         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd78     sLBAboth50unknown        LBA Truncated  both         50
# A78         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd78    sLBAboth50unknown        LBA Truncated  both         50
# t078        sLBAboth50unknown        LBA Truncated  both         50
# B79         sLBAboth50unknown        LBA Truncated  both         50
# v79         sLBAboth50unknown        LBA Truncated  both         50
# v_lMd79     sLBAboth50unknown        LBA Truncated  both         50
# A79         sLBAboth50unknown        LBA Truncated  both         50
# sv_lMd79    sLBAboth50unknown        LBA Truncated  both         50
# t079        sLBAboth50unknown        LBA Truncated  both         50
# B80          sLBAlower10known        LBA Truncated lower         10
# v80          sLBAlower10known        LBA Truncated lower         10
# v_lMd80      sLBAlower10known        LBA Truncated lower         10
# A80          sLBAlower10known        LBA Truncated lower         10
# sv_lMd80     sLBAlower10known        LBA Truncated lower         10
# t080         sLBAlower10known        LBA Truncated lower         10
# B81          sLBAlower10known        LBA Truncated lower         10
# v81          sLBAlower10known        LBA Truncated lower         10
# v_lMd81      sLBAlower10known        LBA Truncated lower         10
# A81          sLBAlower10known        LBA Truncated lower         10
# sv_lMd81     sLBAlower10known        LBA Truncated lower         10
# t081         sLBAlower10known        LBA Truncated lower         10
# B82          sLBAlower10known        LBA Truncated lower         10
# v82          sLBAlower10known        LBA Truncated lower         10
# v_lMd82      sLBAlower10known        LBA Truncated lower         10
# A82          sLBAlower10known        LBA Truncated lower         10
# sv_lMd82     sLBAlower10known        LBA Truncated lower         10
# t082         sLBAlower10known        LBA Truncated lower         10
# B83          sLBAlower10known        LBA Truncated lower         10
# v83          sLBAlower10known        LBA Truncated lower         10
# v_lMd83      sLBAlower10known        LBA Truncated lower         10
# A83          sLBAlower10known        LBA Truncated lower         10
# sv_lMd83     sLBAlower10known        LBA Truncated lower         10
# t083         sLBAlower10known        LBA Truncated lower         10
# B84          sLBAlower10known        LBA Truncated lower         10
# v84          sLBAlower10known        LBA Truncated lower         10
# v_lMd84      sLBAlower10known        LBA Truncated lower         10
# A84          sLBAlower10known        LBA Truncated lower         10
# sv_lMd84     sLBAlower10known        LBA Truncated lower         10
# t084         sLBAlower10known        LBA Truncated lower         10
# B85          sLBAlower10known        LBA Truncated lower         10
# v85          sLBAlower10known        LBA Truncated lower         10
# v_lMd85      sLBAlower10known        LBA Truncated lower         10
# A85          sLBAlower10known        LBA Truncated lower         10
# sv_lMd85     sLBAlower10known        LBA Truncated lower         10
# t085         sLBAlower10known        LBA Truncated lower         10
# B86          sLBAlower10known        LBA Truncated lower         10
# v86          sLBAlower10known        LBA Truncated lower         10
# v_lMd86      sLBAlower10known        LBA Truncated lower         10
# A86          sLBAlower10known        LBA Truncated lower         10
# sv_lMd86     sLBAlower10known        LBA Truncated lower         10
# t086         sLBAlower10known        LBA Truncated lower         10
# B87          sLBAlower10known        LBA Truncated lower         10
# v87          sLBAlower10known        LBA Truncated lower         10
# v_lMd87      sLBAlower10known        LBA Truncated lower         10
# A87          sLBAlower10known        LBA Truncated lower         10
# sv_lMd87     sLBAlower10known        LBA Truncated lower         10
# t087         sLBAlower10known        LBA Truncated lower         10
# B88          sLBAlower10known        LBA Truncated lower         10
# v88          sLBAlower10known        LBA Truncated lower         10
# v_lMd88      sLBAlower10known        LBA Truncated lower         10
# A88          sLBAlower10known        LBA Truncated lower         10
# sv_lMd88     sLBAlower10known        LBA Truncated lower         10
# t088         sLBAlower10known        LBA Truncated lower         10
# B89          sLBAlower10known        LBA Truncated lower         10
# v89          sLBAlower10known        LBA Truncated lower         10
# v_lMd89      sLBAlower10known        LBA Truncated lower         10
# A89          sLBAlower10known        LBA Truncated lower         10
# sv_lMd89     sLBAlower10known        LBA Truncated lower         10
# t089         sLBAlower10known        LBA Truncated lower         10
# B90        sLBAlower10unknown        LBA Truncated lower         10
# v90        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd90    sLBAlower10unknown        LBA Truncated lower         10
# A90        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd90   sLBAlower10unknown        LBA Truncated lower         10
# t090       sLBAlower10unknown        LBA Truncated lower         10
# B91        sLBAlower10unknown        LBA Truncated lower         10
# v91        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd91    sLBAlower10unknown        LBA Truncated lower         10
# A91        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd91   sLBAlower10unknown        LBA Truncated lower         10
# t091       sLBAlower10unknown        LBA Truncated lower         10
# B92        sLBAlower10unknown        LBA Truncated lower         10
# v92        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd92    sLBAlower10unknown        LBA Truncated lower         10
# A92        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd92   sLBAlower10unknown        LBA Truncated lower         10
# t092       sLBAlower10unknown        LBA Truncated lower         10
# B93        sLBAlower10unknown        LBA Truncated lower         10
# v93        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd93    sLBAlower10unknown        LBA Truncated lower         10
# A93        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd93   sLBAlower10unknown        LBA Truncated lower         10
# t093       sLBAlower10unknown        LBA Truncated lower         10
# B94        sLBAlower10unknown        LBA Truncated lower         10
# v94        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd94    sLBAlower10unknown        LBA Truncated lower         10
# A94        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd94   sLBAlower10unknown        LBA Truncated lower         10
# t094       sLBAlower10unknown        LBA Truncated lower         10
# B95        sLBAlower10unknown        LBA Truncated lower         10
# v95        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd95    sLBAlower10unknown        LBA Truncated lower         10
# A95        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd95   sLBAlower10unknown        LBA Truncated lower         10
# t095       sLBAlower10unknown        LBA Truncated lower         10
# B96        sLBAlower10unknown        LBA Truncated lower         10
# v96        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd96    sLBAlower10unknown        LBA Truncated lower         10
# A96        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd96   sLBAlower10unknown        LBA Truncated lower         10
# t096       sLBAlower10unknown        LBA Truncated lower         10
# B97        sLBAlower10unknown        LBA Truncated lower         10
# v97        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd97    sLBAlower10unknown        LBA Truncated lower         10
# A97        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd97   sLBAlower10unknown        LBA Truncated lower         10
# t097       sLBAlower10unknown        LBA Truncated lower         10
# B98        sLBAlower10unknown        LBA Truncated lower         10
# v98        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd98    sLBAlower10unknown        LBA Truncated lower         10
# A98        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd98   sLBAlower10unknown        LBA Truncated lower         10
# t098       sLBAlower10unknown        LBA Truncated lower         10
# B99        sLBAlower10unknown        LBA Truncated lower         10
# v99        sLBAlower10unknown        LBA Truncated lower         10
# v_lMd99    sLBAlower10unknown        LBA Truncated lower         10
# A99        sLBAlower10unknown        LBA Truncated lower         10
# sv_lMd99   sLBAlower10unknown        LBA Truncated lower         10
# t099       sLBAlower10unknown        LBA Truncated lower         10
# B100          sLBAlower2known        LBA Truncated lower          2
# v100          sLBAlower2known        LBA Truncated lower          2
# v_lMd100      sLBAlower2known        LBA Truncated lower          2
# A100          sLBAlower2known        LBA Truncated lower          2
# sv_lMd100     sLBAlower2known        LBA Truncated lower          2
# t0100         sLBAlower2known        LBA Truncated lower          2
# B101          sLBAlower2known        LBA Truncated lower          2
# v101          sLBAlower2known        LBA Truncated lower          2
# v_lMd101      sLBAlower2known        LBA Truncated lower          2
# A101          sLBAlower2known        LBA Truncated lower          2
# sv_lMd101     sLBAlower2known        LBA Truncated lower          2
# t0101         sLBAlower2known        LBA Truncated lower          2
# B102          sLBAlower2known        LBA Truncated lower          2
# v102          sLBAlower2known        LBA Truncated lower          2
# v_lMd102      sLBAlower2known        LBA Truncated lower          2
# A102          sLBAlower2known        LBA Truncated lower          2
# sv_lMd102     sLBAlower2known        LBA Truncated lower          2
# t0102         sLBAlower2known        LBA Truncated lower          2
# B103          sLBAlower2known        LBA Truncated lower          2
# v103          sLBAlower2known        LBA Truncated lower          2
# v_lMd103      sLBAlower2known        LBA Truncated lower          2
# A103          sLBAlower2known        LBA Truncated lower          2
# sv_lMd103     sLBAlower2known        LBA Truncated lower          2
# t0103         sLBAlower2known        LBA Truncated lower          2
# B104          sLBAlower2known        LBA Truncated lower          2
# v104          sLBAlower2known        LBA Truncated lower          2
# v_lMd104      sLBAlower2known        LBA Truncated lower          2
# A104          sLBAlower2known        LBA Truncated lower          2
# sv_lMd104     sLBAlower2known        LBA Truncated lower          2
# t0104         sLBAlower2known        LBA Truncated lower          2
# B105          sLBAlower2known        LBA Truncated lower          2
# v105          sLBAlower2known        LBA Truncated lower          2
# v_lMd105      sLBAlower2known        LBA Truncated lower          2
# A105          sLBAlower2known        LBA Truncated lower          2
# sv_lMd105     sLBAlower2known        LBA Truncated lower          2
# t0105         sLBAlower2known        LBA Truncated lower          2
# B106          sLBAlower2known        LBA Truncated lower          2
# v106          sLBAlower2known        LBA Truncated lower          2
# v_lMd106      sLBAlower2known        LBA Truncated lower          2
# A106          sLBAlower2known        LBA Truncated lower          2
# sv_lMd106     sLBAlower2known        LBA Truncated lower          2
# t0106         sLBAlower2known        LBA Truncated lower          2
# B107          sLBAlower2known        LBA Truncated lower          2
# v107          sLBAlower2known        LBA Truncated lower          2
# v_lMd107      sLBAlower2known        LBA Truncated lower          2
# A107          sLBAlower2known        LBA Truncated lower          2
# sv_lMd107     sLBAlower2known        LBA Truncated lower          2
# t0107         sLBAlower2known        LBA Truncated lower          2
# B108          sLBAlower2known        LBA Truncated lower          2
# v108          sLBAlower2known        LBA Truncated lower          2
# v_lMd108      sLBAlower2known        LBA Truncated lower          2
# A108          sLBAlower2known        LBA Truncated lower          2
# sv_lMd108     sLBAlower2known        LBA Truncated lower          2
# t0108         sLBAlower2known        LBA Truncated lower          2
# B109          sLBAlower2known        LBA Truncated lower          2
# v109          sLBAlower2known        LBA Truncated lower          2
# v_lMd109      sLBAlower2known        LBA Truncated lower          2
# A109          sLBAlower2known        LBA Truncated lower          2
# sv_lMd109     sLBAlower2known        LBA Truncated lower          2
# t0109         sLBAlower2known        LBA Truncated lower          2
# B110        sLBAlower2unknown        LBA Truncated lower          2
# v110        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd110    sLBAlower2unknown        LBA Truncated lower          2
# A110        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd110   sLBAlower2unknown        LBA Truncated lower          2
# t0110       sLBAlower2unknown        LBA Truncated lower          2
# B111        sLBAlower2unknown        LBA Truncated lower          2
# v111        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd111    sLBAlower2unknown        LBA Truncated lower          2
# A111        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd111   sLBAlower2unknown        LBA Truncated lower          2
# t0111       sLBAlower2unknown        LBA Truncated lower          2
# B112        sLBAlower2unknown        LBA Truncated lower          2
# v112        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd112    sLBAlower2unknown        LBA Truncated lower          2
# A112        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd112   sLBAlower2unknown        LBA Truncated lower          2
# t0112       sLBAlower2unknown        LBA Truncated lower          2
# B113        sLBAlower2unknown        LBA Truncated lower          2
# v113        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd113    sLBAlower2unknown        LBA Truncated lower          2
# A113        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd113   sLBAlower2unknown        LBA Truncated lower          2
# t0113       sLBAlower2unknown        LBA Truncated lower          2
# B114        sLBAlower2unknown        LBA Truncated lower          2
# v114        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd114    sLBAlower2unknown        LBA Truncated lower          2
# A114        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd114   sLBAlower2unknown        LBA Truncated lower          2
# t0114       sLBAlower2unknown        LBA Truncated lower          2
# B115        sLBAlower2unknown        LBA Truncated lower          2
# v115        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd115    sLBAlower2unknown        LBA Truncated lower          2
# A115        sLBAlower2unknown        LBA Truncated lower          2
# sv_lMd115   sLBAlower2unknown        LBA Truncated lower          2
# t0115       sLBAlower2unknown        LBA Truncated lower          2
# B116        sLBAlower2unknown        LBA Truncated lower          2
# v116        sLBAlower2unknown        LBA Truncated lower          2
# v_lMd116    sLBAlower2unknown        LBA Truncated lower          2
# v952       1.753538e+00      1.0000000
# v_lMd952   1.925923e-01      0.4000000
# s_lMd952  -1.558211e-01     -0.2876821
# t01432    -1.922825e+00     -1.6094379
# B953       1.668331e+00      1.0986123
# v953       1.773646e+00      1.0000000
# v_lMd953   2.048999e-01      0.4000000
# s_lMd953  -3.326595e-01     -0.2876821
# t01433    -2.226594e+00     -1.6094379
# B954       1.578140e+00      1.0986123
# v954       1.807273e+00      1.0000000
# v_lMd954   2.188722e-01      0.4000000
# s_lMd954   7.062001e-03     -0.2876821
# t01434    -1.363694e+00     -1.6094379
# B955       1.685630e+00      1.0986123
# v955       1.802766e+00      1.0000000
# v_lMd955   1.614907e-01      0.4000000
# s_lMd955  -3.745123e-01     -0.2876821
# t01435    -2.230779e+00     -1.6094379
# B956       1.635917e+00      1.0986123
# v956       1.837965e+00      1.0000000
# v_lMd956   1.738059e-01      0.4000000
# s_lMd956  -3.790706e-02     -0.2876821
# t01436    -1.509877e+00     -1.6094379
# B957       1.668210e+00      1.0986123
# v957       1.843435e+00      1.0000000
# v_lMd957   1.160270e-01      0.4000000
# s_lMd957  -3.197072e-01     -0.2876821
# t01437    -1.735364e+00     -1.6094379
# B958       1.714198e+00      1.0986123
# v958       1.822219e+00      1.0000000
# v_lMd958   1.853833e-01      0.4000000
# s_lMd958  -4.210045e-01     -0.2876821
# t01438    -2.285601e+00     -1.6094379
# B959       1.697121e+00      1.0986123
# v959       1.813097e+00      1.0000000
# v_lMd959   1.627297e-01      0.4000000
# s_lMd959  -4.053270e-01     -0.2876821
# t01439    -2.280850e+00     -1.6094379

# %%
EMCs_expanded$percentage <- as.numeric(EMCs_expanded$percentage)
EMCs_expanded %>%
  ggplot(aes(true_parameter, Median, color = subject)) +
  geom_point(size = 0.1) +
  geom_abline() +
  facet_grid(tail + percentage ~ model_name + censoring, scales = "free_y") +
  geom_errorbar(aes(ymin = q25, ymax = q75))
# Out:
# Warning: Removed 9 rows containing missing values or values outside the scale range
# (`geom_point()`).

# %%
between(parsLBA, EMCs_expanded$q25[EMCs_expanded$EMC == "sMLBAlower2known"][1:6], EMCs_expanded$q75[EMCs_expanded$EMC == "sMLBAlower2known"][1:6])
# Out:
# [1]  TRUE FALSE FALSE FALSE  TRUE  TRUE

# %%
# Calculate RMSE per group
EMCs_RMSEs <- EMCs_expanded %>%
  group_by(subject, EMC, percentage, response_known, 
           tail, censoring, model_name) %>%
  summarise(
    RMSE = sqrt(mean((Median - true_parameter)^2)),  # Calculate RMSE
    .groups = 'drop'  # Ungroup after summarizing
  )

# %%
big_model <- aov(RMSE ~ percentage * response_known *
           tail * censoring * model_name, data = EMCs_RMSEs)

summary(big_model)
# Out:
#                                                       Df Sum Sq Mean Sq F value
# percentage                                             1  39.74   39.74 786.596
# response_known                                         1   0.26    0.26   5.058
# tail                                                   2   7.63    3.81  75.479
# censoring                                              1  18.08   18.08 357.993
# model_name                                             2  81.76   40.88 809.211
# percentage:response_known                              1   0.33    0.33   6.611
# percentage:tail                                        2   0.38    0.19   3.737
# response_known:tail                                    2   0.46    0.23   4.575
# percentage:censoring                                   1   1.50    1.50  29.694
# response_known:censoring                               1   0.43    0.43   8.511
# tail:censoring                                         2  13.31    6.66 131.753
# percentage:model_name                                  2  15.96    7.98 157.956
# response_known:model_name                              2   1.62    0.81  16.070
# tail:model_name                                        4   6.78    1.69  33.530
# censoring:model_name                                   2   0.21    0.11   2.118
# percentage:response_known:tail                         2   0.66    0.33   6.533
# percentage:response_known:censoring                    1   0.56    0.56  11.016
# percentage:tail:censoring                              2   4.01    2.00  39.686
# response_known:tail:censoring                          2   0.28    0.14   2.723
# percentage:response_known:model_name                   2   1.68    0.84  16.670
# percentage:tail:model_name                             4   2.21    0.55  10.939
# response_known:tail:model_name                         4   1.26    0.32   6.258
# percentage:censoring:model_name                        2   3.13    1.57  31.012
# response_known:censoring:model_name                    2   1.67    0.83  16.480
# tail:censoring:model_name                              4  14.23    3.56  70.406
# percentage:response_known:tail:censoring               2   0.71    0.35   7.014
# percentage:response_known:tail:model_name              4   1.39    0.35   6.873
# percentage:response_known:censoring:model_name         2   1.93    0.96  19.068
# percentage:tail:censoring:model_name                   4   4.75    1.19  23.504
# response_known:tail:censoring:model_name               4   0.94    0.23   4.650
# percentage:response_known:tail:censoring:model_name    4   1.67    0.42   8.265
# Residuals                                           1359  68.65    0.05
#                                                       Pr(>F)
# percentage                                           < 2e-16 ***
# response_known                                      0.024668 *
# tail                                                 < 2e-16 ***
# censoring                                            < 2e-16 ***
# model_name                                           < 2e-16 ***
# percentage:response_known                           0.010243 *
# percentage:tail                                     0.024073 *
# response_known:tail                                 0.010468 *
# percentage:censoring                                6.00e-08 ***
# response_known:censoring                            0.003588 **
# tail:censoring                                       < 2e-16 ***
# percentage:model_name                                < 2e-16 ***
# response_known:model_name                           1.26e-07 ***
# tail:model_name                                      < 2e-16 ***
# censoring:model_name                                0.120615
# percentage:response_known:tail                      0.001501 **
# percentage:response_known:censoring                 0.000927 ***
# percentage:tail:censoring                            < 2e-16 ***
# response_known:tail:censoring                       0.066065 .
# percentage:response_known:model_name                7.04e-08 ***
# percentage:tail:model_name                          9.87e-09 ***
# response_known:tail:model_name                      5.46e-05 ***
# percentage:censoring:model_name                     6.76e-14 ***
# response_known:censoring:model_name                 8.48e-08 ***
# tail:censoring:model_name                            < 2e-16 ***
# percentage:response_known:tail:censoring            0.000932 ***
# percentage:response_known:tail:model_name           1.78e-05 ***
# percentage:response_known:censoring:model_name      6.81e-09 ***
# percentage:tail:censoring:model_name                 < 2e-16 ***
# response_known:tail:censoring:model_name            0.000990 ***
# percentage:response_known:tail:censoring:model_name 1.38e-06 ***
# Residuals
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
# 9 observations deleted due to missingness

# %%
#| label: RMSD_both
#| fig-cap: Root Mean Squared Errors in each condition
#| apa-note: For each model, the RMSE was computed over all subject fits.

na.omit(EMCs_RMSEs) %>%
  ggplot(aes(censoring, RMSE, fill = interaction(percentage, censoring, sep = "% "))) +
  facet_grid(tail + response_known ~ model_name) +
  scale_fill_brewer(palette = "PuOr") +
  stat_summary(position = "dodge", geom = "bar", fun = "mean") +
  labs(fill = "Missing")
